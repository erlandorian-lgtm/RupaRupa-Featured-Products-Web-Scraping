# %% [markdown]
# ## Checking `robots.txt` before scraping
#
# Since this is a real commercial site (not a scraping sandbox), I checked
# `https://www.ruparupa.com/robots.txt` before writing any code.
#
# The target page (`/ms/promo-9-9`) is not listed under any `Disallow` rule for
# `User-agent: *`, so scraping it is permitted. The disallowed paths are mostly
# private/transactional pages (`/my-account`, `/checkout`, `/cart`, `/dashboard`)
# — none of which apply here.
#
# This scrape was a one-time, small-scale run for learning purposes, with a
# delay between requests (`time.sleep()`), and the data is not redistributed
# or used commercially.
#
# "This notebook is designed to run in Google Colab (uses Colab-specific commands for installing Chrome/Selenium)."

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Setting up Selenium

# %%
# !apt-get update
# !apt-get install -y chromium-chromedriver
# !pip install selenium
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu noble InRelease
# Get:2 https://cli.github.com/packages stable InRelease [4,685 B]
# Get:3 http://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease [3,631 B]
# Get:6 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu noble InRelease [9,161 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Get:9 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [2,151 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [1,564 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [1,908 kB]
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ Packages [72.4 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu noble/main amd64 Packages [2,979 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu noble/main all Packages [10.1 MB]
# Get:15 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1,530 kB]
# Get:16 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [1,242 kB]
# Get:17 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [1,796 kB]
# Fetched 23.8 MB in 3s (7,110 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 snapd squashfs-tools systemd-hwe-hwdb
#   udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 snapd
#   squashfs-tools systemd-hwe-hwdb udev
# 0 upgraded, 8 newly installed, 0 to remove and 28 not upgraded.
# Need to get 39.4 MB of archives.
# After this operation, 149 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 apparmor amd64 4.0.1really4.0.1-0ubuntu0.24.04.7 [640 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/main amd64 squashfs-tools amd64 1:4.6.1-1build1 [189 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 udev amd64 255.4-1ubuntu8.17 [1,875 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/main amd64 libfuse3-3 amd64 3.14.0-5build1 [83.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 snapd amd64 2.76.3+ubuntu24.04 [36.6 MB]
# Get:6 http://archive.ubuntu.com/ubuntu noble/universe amd64 chromium-browser amd64 2:1snap1-0ubuntu2 [50.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 systemd-hwe-hwdb all 255.1.7 [3,716 B]
# Get:8 http://archive.ubuntu.com/ubuntu noble/universe amd64 chromium-chromedriver amd64 2:1snap1-0ubuntu2 [2,308 B]
# Fetched 39.4 MB in 1s (64.9 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 122797 files and directories currently installed.)
# Preparing to unpack .../apparmor_4.0.1really4.0.1-0ubuntu0.24.04.7_amd64.deb ...
# Unpacking apparmor (4.0.1really4.0.1-0ubuntu0.24.04.7) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.6.1-1build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.6.1-1build1) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../udev_255.4-1ubuntu8.17_amd64.deb ...
# Unpacking udev (255.4-1ubuntu8.17) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.14.0-5build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.14.0-5build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.76.3+ubuntu24.04_amd64.deb ...
# Unpacking snapd (2.76.3+ubuntu24.04) ...
# Setting up apparmor (4.0.1really4.0.1-0ubuntu0.24.04.7) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /usr/lib/systemd/system/apparmor.service.
# Setting up squashfs-tools (1:4.6.1-1build1) ...
# Setting up udev (255.4-1ubuntu8.17) ...
# Creating group 'input' with GID 996.
# Creating group 'sgx' with GID 995.
# Creating group 'kvm' with GID 994.
# Creating group 'render' with GID 993.
# Setting up libfuse3-3:amd64 (3.14.0-5build1) ...
# Setting up snapd (2.76.3+ubuntu24.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /usr/lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /usr/lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /usr/lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /usr/lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /usr/lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /usr/lib/systemd/system/snapd.seeded.service.
# Unit /usr/lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /usr/lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /usr/lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /usr/lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /usr/lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 123360 files and directories currently installed.)
# Preparing to unpack .../chromium-browser_2%3a1snap1-0ubuntu2_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (2:1snap1-0ubuntu2) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../systemd-hwe-hwdb_255.1.7_all.deb ...
# Unpacking systemd-hwe-hwdb (255.1.7) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_2%3a1snap1-0ubuntu2_amd64.deb ...
# Unpacking chromium-chromedriver (2:1snap1-0ubuntu2) ...
# Setting up systemd-hwe-hwdb (255.1.7) ...
# Setting up chromium-browser (2:1snap1-0ubuntu2) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (2:1snap1-0ubuntu2) ...
# Processing triggers for udev (255.4-1ubuntu8.17) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for dbus (1.14.10-4ubuntu4.1) ...
# Collecting selenium
#   Downloading selenium-4.49.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: certifi>=2026.2.25 in /usr/local/lib/python3.13/dist-packages (from selenium) (2026.7.22)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.34.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from selenium) (4.16.0)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from selenium) (1.9.2)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from trio<1.0,>=0.31.0->selenium) (26.1.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from trio<1.0,>=0.31.0->selenium) (3.19)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.13/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.16.0 in /usr/local/lib/python3.13/dist-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.49.0-py3-none-any.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 70.7 MB/s eta 0:00:00
# Downloading trio-0.34.0-py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 kB 23.0 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 8.4 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, urllib3, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# Successfully installed outcome-1.3.0.post0 selenium-4.49.0 sortedcontainers-2.4.0 trio-0.34.0 trio-websocket-0.12.2 urllib3-2.7.0 wsproto-1.3.2

# %%
# !wget -q https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !apt install -y ./google-chrome-stable_current_amd64.deb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'google-chrome-stable' instead of './google-chrome-stable_current_amd64.deb'
# The following additional packages will be installed:
#   at-spi2-common at-spi2-core gsettings-desktop-schemas libatk-bridge2.0-0t64
#   libatk1.0-0t64 libatspi2.0-0t64 libxcomposite1 libxtst6 session-migration
# The following NEW packages will be installed:
#   at-spi2-common at-spi2-core google-chrome-stable gsettings-desktop-schemas
#   libatk-bridge2.0-0t64 libatk1.0-0t64 libatspi2.0-0t64 libxcomposite1
#   libxtst6 session-migration
# 0 upgraded, 10 newly installed, 0 to remove and 28 not upgraded.
# Need to get 331 kB/142 MB of archives.
# After this operation, 456 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble/main amd64 at-spi2-common all 2.52.0-1build1 [8,674 B]
# Get:2 http://archive.ubuntu.com/ubuntu noble/main amd64 libatk1.0-0t64 amd64 2.52.0-1build1 [55.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble/main amd64 libatspi2.0-0t64 amd64 2.52.0-1build1 [80.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/main amd64 libatk-bridge2.0-0t64 amd64 2.52.0-1build1 [66.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcomposite1 amd64 1:0.4.5-1build3 [6,320 B]
# Get:6 http://archive.ubuntu.com/ubuntu noble/main amd64 libxtst6 amd64 2:1.2.3-1.1build1 [12.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/main amd64 session-migration amd64 0.3.9build1 [9,034 B]
# Get:8 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gsettings-desktop-schemas all 46.1-0ubuntu1 [35.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble/main amd64 at-spi2-core amd64 2.52.0-1build1 [56.6 kB]
# Get:10 /content/google-chrome-stable_current_amd64.deb google-chrome-stable amd64 153.0.8010.36-1 [142 MB]
# Fetched 331 kB in 1s (247 kB/s)
# Selecting previously unselected package at-spi2-common.
# (Reading database ... 123389 files and directories currently installed.)
# Preparing to unpack .../0-at-spi2-common_2.52.0-1build1_all.deb ...
# Unpacking at-spi2-common (2.52.0-1build1) ...
# Selecting previously unselected package libatk1.0-0t64:amd64.
# Preparing to unpack .../1-libatk1.0-0t64_2.52.0-1build1_amd64.deb ...
# Unpacking libatk1.0-0t64:amd64 (2.52.0-1build1) ...
# Selecting previously unselected package libatspi2.0-0t64:amd64.
# Preparing to unpack .../2-libatspi2.0-0t64_2.52.0-1build1_amd64.deb ...
# Unpacking libatspi2.0-0t64:amd64 (2.52.0-1build1) ...
# Selecting previously unselected package libatk-bridge2.0-0t64:amd64.
# Preparing to unpack .../3-libatk-bridge2.0-0t64_2.52.0-1build1_amd64.deb ...
# Unpacking libatk-bridge2.0-0t64:amd64 (2.52.0-1build1) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../4-libxcomposite1_1%3a0.4.5-1build3_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build3) ...
# Selecting previously unselected package google-chrome-stable.
# Preparing to unpack .../5-google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (153.0.8010.36-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../6-libxtst6_2%3a1.2.3-1.1build1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1.1build1) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../7-session-migration_0.3.9build1_amd64.deb ...
# Unpacking session-migration (0.3.9build1) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../8-gsettings-desktop-schemas_46.1-0ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (46.1-0ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../9-at-spi2-core_2.52.0-1build1_amd64.deb ...
# Unpacking at-spi2-core (2.52.0-1build1) ...
# Setting up session-migration (0.3.9build1) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libxtst6:amd64 (2:1.2.3-1.1build1) ...
# Setting up libatspi2.0-0t64:amd64 (2.52.0-1build1) ...
# Setting up at-spi2-common (2.52.0-1build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build3) ...
# Setting up gsettings-desktop-schemas (46.1-0ubuntu1) ...
# Setting up libatk1.0-0t64:amd64 (2.52.0-1build1) ...
# Setting up libatk-bridge2.0-0t64:amd64 (2.52.0-1build1) ...
# Setting up google-chrome-stable (153.0.8010.36-1) ...
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/google-chrome (google-chrome) in auto mode
# Processing triggers for libc-bin (2.39-0ubuntu8.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for libglib2.0-0t64:amd64 (2.80.0-6ubuntu3.8) ...
# Setting up at-spi2-core (2.52.0-1build1) ...

# %%
# !google-chrome --version
# Out:
# Google Chrome 153.0.8010.36

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument("--headless")        # no visible browser window 
options.add_argument("--no-sandbox")       # required in Colab's restricted environment
options.add_argument("--disable-dev-shm-usage")  # avoids a common Colab memory crash
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")

driver = webdriver.Chrome(options=options)

# %%
import time

driver.get("https://www.ruparupa.com/ms/promo-9-9")
print(driver.title)

for i in range(5):
  driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
  time.sleep(2)
  print(f"Scrolled {i+1} times")
# Out:
# Promo 9.9 2026: Diskon & Voucher Belanja | ruparupa
# Scrolled 1 times
# Scrolled 2 times
# Scrolled 3 times
# Scrolled 4 times
# Scrolled 5 times

# %% [markdown]
# ## finding how many products there are in product card actually

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

products = soup.find_all("div", class_="row product-card")
print(len(products))
# Out:
# 72

# %% [markdown]
# ## Checking if there are duplicate rows / objects

# %%
product_names = []

for p in products:
    name_tag = p.find("span", class_="product__name")
    if name_tag:
        product_names.append(name_tag.get_text(strip=True))

print("Total found:", len(product_names))
print("Unique names:", len(set(product_names)))
# Out:
# Total found: 72
# Unique names: 71

# %% [markdown]
# ## remove the duplicated objects

# %%
seen = set()
unique_products = []

for p in products:
    name_tag = p.find("span", class_="product__name")
    if name_tag:
        name = name_tag.get_text(strip=True)
        if name not in seen:
            seen.add(name)
            unique_products.append(p)

print(len(unique_products))
# Out:
# 71

# %% [markdown]
# ## Extracting product data

# %%
def extract_ruparupa_product(product_div):
  ##Product name
  name_tag = product_div.find("span", class_="product__name")
  name = name_tag.get_text(strip=True) if name_tag else None ##strip used for removing space and white lines

  ##Initial Price
  initial_price_tag = product_div.find("div", class_="price__initial")
  initial_price = initial_price_tag.get_text(strip=True) if initial_price_tag else None

  ##Discount
  discount_tag = product_div.find("div", class_="price__discount")
  discount = discount_tag.get_text(strip=True) if discount_tag else None

  ##Product URL
  product_url_tag = product_div.find("a")
  product_url = product_url_tag["href"] if product_url_tag else None

  ##Image Url
  image_url_tag = product_div.find("img")
  image_url = image_url_tag["src"] if image_url_tag else None

  ##Final Price
  final_price_tag = product_div.find("div", class_="price__real")
  final_price = final_price_tag.get_text(strip=True) if final_price_tag else None

  ##Rating, used attrs when you're not using class_ / spans data
  rating_tag = product_div.find("span", attrs={"data-testid":"lblTotalRating"})
  rating = rating_tag.get_text(strip=True) if rating_tag else None

  ##Review
  review_tag = product_div.find("span", attrs={"data-testid":"lblTotalUlasan"})
  review = review_tag.get_text(strip=True) if review_tag else None

  return {"name" : name, "initial_price" : initial_price, "product_url" : product_url,
          "image_url" : image_url,"discount" : discount, "final_price" : final_price,
          "rating" : rating,"review" : review}

# %%
products_data = []

for p in unique_products:
    data = extract_ruparupa_product(p)
    products_data.append(data)

for item in products_data:
  print(item)
# Out:
# {'name': 'Krisbow Sync Smart Air Sterilizer 2-in-1 Bladeless CADR 50 m3/jam 20 M2 - Hitam', 'initial_price': 'Rp2.299.000', 'product_url': 'https://www.ruparupa.com/p/klaz-air-sterilizer-2in1-bladeless-hitam.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10580147&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/fit-in/240x240/filters:format(webp)/filters:quality(90)/ruparupa-com/image/upload/Products/10580147_1.jpg', 'discount': '25%', 'final_price': 'Rp1.724.250', 'rating': '5|', 'review': '7(ulasan)'}
# {'name': 'Informa Bronto Sofa Bed Fabric - Hijau', 'initial_price': 'Rp4.299.000', 'product_url': 'https://www.ruparupa.com/p/informa-bronto-sofa-bed-fabric-hijau.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10570059&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/fit-in/240x240/filters:format(webp)/filters:quality(90)/ruparupa-com/image/upload/Products/10570059_1.jpg', 'discount': '20%', 'final_price': 'Rp3.399.000', 'rating': '5|', 'review': '41(ulasan)'}
# {'name': 'Memoo Kipas Angin Portable Rechargeable - Biru', 'initial_price': 'Rp139.900', 'product_url': 'https://www.ruparupa.com/p/memoo-kipas-angin-portable-rechargeable-biru.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10569583&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': '64%', 'final_price': 'Rp49.900', 'rating': '5|', 'review': '136(ulasan)'}
# {'name': 'Kels Miro Air Purifier UV 18 m2 CADR 130 m3/jam - Putih', 'initial_price': 'Rp1.499.000', 'product_url': 'https://www.ruparupa.com/p/kels-miro-penjernih-udara-uv-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10447788&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': '33%', 'final_price': 'Rp999.000', 'rating': '5|', 'review': '37(ulasan)'}
# {'name': 'Selma Haru Meja Sisi Dengan Penyimpanan - Hitam', 'initial_price': 'Rp359.000', 'product_url': 'https://www.ruparupa.com/p/selma-haru-meja-sisi-dengan-penyimpanan-hitam.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10635223&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/fit-in/240x240/filters:format(webp)/filters:quality(90)/ruparupa-com/image/upload/Products/10635223_1.jpg', 'discount': '27%', 'final_price': 'Rp259.000', 'rating': '5|', 'review': '12(ulasan)'}
# {'name': 'Paso Ukuran 34-38 Sepatu Roda Inline Skate Captain America - Biru/Merah', 'initial_price': 'Rp1.649.900', 'product_url': 'https://www.ruparupa.com/p/paso-ukuran-34-38-sepatu-roda-inline-skate-captain-america-biru-merah.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10630095&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/fit-in/240x240/filters:format(webp)/filters:quality(90)/ruparupa-com/image/upload/Products/10630095_1.jpg', 'discount': '45%', 'final_price': 'Rp899.900', 'rating': None, 'review': None}
# {'name': 'Krisbow Rak Besi 5 Tingkat 90x40x183 cm - Hitam', 'initial_price': 'Rp1.699.000', 'product_url': 'https://www.ruparupa.com/p/krisbow-rak-besi-5-tingkat-hitam.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10553021&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': '41%', 'final_price': 'Rp999.000', 'rating': '5|', 'review': '171(ulasan)'}
# {'name': 'Informa Topaz Meja Tamu Dengan Penyimpanan - Hitam', 'initial_price': 'Rp199.000', 'product_url': 'https://www.ruparupa.com/p/topaz-meja-dengan-penyimpanan-hitam.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=
shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': '20%', 'final_price': 'Rp103.920', 'rating': '5 |', 'review': '2 (ulasan)'}
# {'name': 'Krisbow Strata Rak Besi 5 Tingkat 90x40x183 cm - Putih', 'initial_price': 'Rp1.699.000', 'product_url': 'https://www.ruparupa.com/p/krisbow-90x40x183-cm-strata-rak-besi-5-tingkat-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10602273&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': '41%', 'final_price': 'Rp999.000', 'rating': '5 |', 'review': '87 (ulasan)'}
# {'name': 'Krisbow Sync Smart Bohlam LED Bluetooth 14 Watt 1400 Lumen RGBCW E27 V2 - Mix', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/krisbow-sync-smart-bohlam-led-bluetooth-14-watt-rgbcw.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10558296&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp129.900', 'rating': '5 |', 'review': '232 (ulasan)'}
# {'name': 'Informa Kain Lap Dapur Rainbow Sky Set 7 pcs', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/kain-lap-dapur-set-7-pcs-rainbow-sky.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10376730&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp79.000', 'rating': '4.9 |', 'review': '128 (ulasan)'}
# {'name': 'Forhom Jam Weker Anak Cube Random', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/forhom-jam-weker-anak-cube-random.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10611323&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp69.900', 'rating': '5 |', 'review': '13 (ulasan)'}
# {'name': 'Informa London Z Bangku Metal - Hitam', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/london-z-bangku-hitam.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10129763&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp459.000', 'rating': '5 |', 'review': '93 (ulasan)'}
# {'name': 'Kindla Set 6 Pcs Abercio Perlengkapan Makan Bayi - Abu-Abu', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/kindla-set-6-pcs-abercio-perlengkapan-makan-anak-abu-abu.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10610521&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': None, 'final_price': 'Rp399.900', 'rating': '5 |', 'review': '9 (ulasan)'}
# {'name': 'Informa Jason Rak Besi 5 Tingkat - Putih', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/informa-jason-rak-besi-5-tingkat-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10493197&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp699.000', 'rating': '4.7 |', 'review': '370 (ulasan)'}
# {'name': 'Ataru Botol Minum Tritan Dengan Pemeras Jeruk Stitch Round 550 ml - Biru', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/ataru-550-ml-botol-minum-dengan-pemeras-jeruk-stitch-round-biru.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10642676&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp149.900', 'rating': None, 'review': None}
# {'name': 'Informa Lorra Kursi Makan Fabric - Cokelat', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/informa-lorra-kursi-makan-fabric-cokelat.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10640690&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp999.000', 'rating': '5 |', 'review': '5 (ulasan)'}
# {'name': 'Arthome Iris Akiko Tanaman Artifisial Succulent Dengan Pot 8x8x9.5 cm Random', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/arthome-iris-akiko-tanaman-artifisial-sukulen.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10545501&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp49.900', 'rating': '5 |', 'review': '20 (ulasan)'}
# {'name': 'Selma Melton Tempat Sampah Pedal Plastik 6.5 Liter - Oranye', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/selma-6-5-ltr-tempat-sampah-pedal-orange.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10509715&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp159.000', 'rating': '4.9 |', 'review': '27 (ulasan)'}
# {'name': 'Picas Exta Stoples Plastik 2.5 Liter Transparan - Hijau', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/picas-2-5-ltr-exta-stoples-plastik-hijau.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10609587&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp89.900', 'rating': '5 |', 'review': '14 (ulasan)'}
# {'name': 'Informa London Z Bangku Bar Metal - Merah', 'initial_price': None, 'product_url': 'https://www.ruparupa.com/p/london-z-bangku-bar-merah.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10149933&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': None, 'final_price': 'Rp659.000', 'rating': '5 |', 'review': '14 (ulasan)'}
# {'name': 'Stora Rak Troli Lipat 3 Tingkat 43x27x83 cm - Putih', 'initial_price': 'Rp499.900', 'product_url': 'https://www.ruparupa.com/p/stora-43x27x83-cm-rak-troli-lipat-3-tingkat-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10569310&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '40%', 'final_price': 'Rp299.900', 'rating': '5 |', 'review': '162 (ulasan)'}
# {'name': 'Ataru Tas Kosmetik Puffy Square Front Zip - Pink', 'initial_price': 'Rp119.900', 'product_url': 'https://www.ruparupa.com/p/ataru-tas-kosmetik-puffy-square-front-zip-pink.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10695448&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/media/promotion/ruparupa/9-9-2026/onsite/ribbon.png', 'discount': '24%', 'final_price': 'Rp90.000', 'rating': None, 'review': None}
# {'name': 'Informa Harmon Kursi - Putih', 'initial_price': 'Rp419.000', 'product_url': 'https://www.ruparupa.com/p/harmon-kursi-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10410167&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '28%', 'final_price': 'Rp299.000', 'rating': '4.9 |', 'review': '85 (ulasan)'}
# {'name': 'Kris Kipas Angin Meja 6 Inch 30 Watt - Putih', 'initial_price': 'Rp469.900', 'product_url': 'https://www.ruparupa.com/p/kris-6-inci-kipas-angin-meja-30-watt-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10556915&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '36%', 'final_price': 'Rp299.900', 'rating': '5 |', 'review': '73 (ulasan)'}
# {'name': 'Cruzer Dinos Chomp Grabber - Mix', 'initial_price': 'Rp219.900', 'product_url': 'https://www.ruparupa.com/p/cruzer-dinos-chomp-grabber-mix.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10629764&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '50%', 'final_price': 'Rp109.950', 'rating': '5 |', 'review': '7 (ulasan)'}
# {'name': 'Stora Gantungan Pakaian Dengan Keranjang Single - Putih', 'initial_price': 'Rp279.900', 'product_url': 'https://www.ruparupa.com/p/stora-gantungan-pakaian-dengan-keranjang-single-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10610823&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '10%', 'final_price': 'Rp251.910', 'rating': None, 'review': None}
# {'name': 'Eglare Lampu Meja LED Levitating Balance 4 Watt - Putih', 'initial_price': 'Rp199.900', 'product_url': 'https://www.ruparupa.com/p/eglare-lampu-meja-levitating-balance-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10632795&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '25%', 'final_price': 'Rp149.000', 'rating': '5 |', 'review': '2 (ulasan)'}
# {'name': 'Kels Blow Dryer Brush D380 - Pink', 'initial_price': 'Rp359.000', 'product_url': 'https://www.ruparupa.com/p/kels-blow-dryer-brush-d380-pink.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10489480&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '20%', 'final_price': 'Rp287.200', 'rating': '5 |', 'review': '33 (ulasan)'}
# {'name': 'Odi Meja Laptop Lipat Dengan Mouse Pad - Cokelat Muda', 'initial_price': 'Rp249.900', 'product_url': 'https://www.ruparupa.com/p/odi-meja-lipat-laptop-cokelat.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10437779&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '28%', 'final_price': 'Rp179.900', 'rating': '4.9 |', 'review': '206 (ulasan)'}
# {'name': 'Kris Nemona Air Wajan Panggang & Hot Pot 2 In 1 Non-Stick Ceramic Coating - Putih', 'initial_price': 'Rp899.900', 'product_url': 'https://www.ruparupa.com/p/kris-nemona-air-wajan-panggang-hot-pot-2-in-1-square.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10583320&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '45%', 'final_price': 'Rp494.945', 'rating': '5 |', 'review': '4 (ulasan)'}
# {'name': 'Selma Tom Rak Laundry - Abu-Abu', 'initial_price': 'Rp179.000', 'product_url': 'https://www.ruparupa.com/p/selma-tom-rak-laundry.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10572780&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '44%', 'final_price': 'Rp99.000', 'rating': '4.7 |', 'review': '13 (ulasan)'}
# {'name': 'Kris Air Fryer 2.8 Liter 600 Watt - Putih', 'initial_price': 'Rp499.900', 'product_url': 'https://www.ruparupa.com/p/kris-air-fryer-manual-2-8-liter-600-watt-putih.html??itm_source=promo-product-promo-9-9&itm_campaign=promo-9-9&itm_device=desktop&itm_term=10696465&shipping_type_clicked=none', 'image_url': 'https://cdn.ruparupa.io/736x112/media/tahu-asset/IMAGE_TAHU_ribbon_1777867011.png', 'discount': '20%', 'final_price': 'Rp399.900', 'rating': '5 |', 'review': '11 (ulasan)'}

# %% [markdown]
# ## Exporting to CSV

# %%
df = pd.DataFrame(products_data)
df.head()

df.to_csv("ruparupa_products.csv", index=False)

# %%
from google.colab import files
files.download("ruparupa_products.csv")

# %%
driver.quit()
# Out:
# <bound method LocalWebDriver.quit of <selenium.webdriver.chrome.webdriver.WebDriver (session="b009acd424279da6f702f4d68e03adda")>>
